# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('reported_hospital_utilization_20200925_2243.csv')

# %%
df
# Out:
#    state  hospital_onset_covid  hospital_onset_covid_coverage  inpatient_beds  \
# 0     PA                     5                            192           29291
# 1     PR                     3                             69            9664
# 2     RI                     3                             14            2218
# 3     SC                     7                             76           10234
# 4     SD                     1                             57            2101
# 5     TN                     7                            110           17871
# 6     TX                   109                            548           66822
# 7     UT                     5                             54            5369
# 8     VA                    21                             98           17548
# 9     VI                     0                              2             188
# 10    VT                     0                             16            1254
# ...

# %%
df2 = pd.DataFrame(df, columns=['inpatient_beds_utilization','percent_of_inpatients_with_covid','adult_icu_bed_utilization','total_adult_patients_hospitalized_confirmed_covid','total_pediatric_patients_hospitalized_confirmed_covid','adult_icu_bed_covid_utilization'])
dataPA = df2.loc[0] #prints all the data for PA
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\PA.txt', dataPA, fmt='%s')

dataRI = df2.loc[2] #prints all the data for RI
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\RI.txt', dataRI, fmt='%s')

#etc, find and replace for finding specific states

dataSC = df2.loc[3] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\SC.txt', dataSC, fmt='%s')

dataSD = df2.loc[4] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\SD.txt', dataSD, fmt='%s')

dataTN = df2.loc[5] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\TN.txt', dataTN, fmt='%s')

dataTX = df2.loc[6] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\RI.txt', dataTX, fmt='%s')

dataUT = df2.loc[7]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\UT.txt', dataUT, fmt='%s')

dataVA = df2.loc[8]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\VA.txt', dataVA, fmt='%s')

dataVT = df2.loc[10] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\VT.txt', dataVT, fmt='%s')

dataWA = df2.loc[11]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\WA.txt', dataWA, fmt='%s')

dataWI = df2.loc[12] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\WI.txt', dataWI, fmt='%s')

dataAK = df2.loc[13]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\AK.txt', dataAK, fmt='%s')

dataAL = df2.loc[14] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\AL.txt', dataAL, fmt='%s')

dataAR = df2.loc[15]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\AR.txt', dataAR, fmt='%s')

dataAZ = df2.loc[16] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\AZ.txt', dataAZ, fmt='%s')

dataCA = df2.loc[17]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\CA.txt', dataCA, fmt='%s')

dataCO = df2.loc[18]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\CO.txt', dataCO, fmt='%s')

dataCT = df2.loc[19] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\CT.txt', dataCT, fmt='%s')

#should probably include DC, for future reference

dataDE = df2.loc[21]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\DE.txt', dataDE, fmt='%s')

dataFL = df2.loc[22] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\FL.txt', dataFL, fmt='%s')

dataGA = df2.loc[23]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\GA.txt', dataGA, fmt='%s')

dataHI = df2.loc[24] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\HI.txt', dataHI, fmt='%s')

dataIA = df2.loc[25]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\IA.txt', dataIA, fmt='%s')

dataMS = df2.loc[26] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\MS.txt', dataMS, fmt='%s')

dataMT = df2.loc[27]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\MT.txt', dataMT, fmt='%s')

dataNC = df2.loc[28] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\NC.txt', dataNC, fmt='%s')

dataND = df2.loc[29]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\ND.txt', dataND, fmt='%s')

dataNE = df2.loc[30] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\NE.txt', dataNE, fmt='%s')

dataNH = df2.loc[31]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\NH.txt', dataNH, fmt='%s')

dataNJ = df2.loc[32] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\NJ.txt', dataNJ, fmt='%s')

dataNM = df2.loc[33]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\NM.txt', dataNM, fmt='%s')

dataNV = df2.loc[34] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\NV.txt', dataNV, fmt='%s')

dataNY = df2.loc[35]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\NY.txt', dataNY, fmt='%s')

dataOH = df2.loc[36] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\OH.txt', dataOH, fmt='%s')

dataOK = df2.loc[37]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\OK.txt', dataOK, fmt='%s')

dataOR = df2.loc[38] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\OR.txt', dataOR, fmt='%s')

dataID = df2.loc[39]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\ID.txt', dataID, fmt='%s')

dataIL = df2.loc[40] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\IL.txt', dataIL, fmt='%s')

dataIN = df2.loc[41]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\IN.txt', dataIN, fmt='%s')

dataKS = df2.loc[42] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\KS.txt', dataKS, fmt='%s')

dataKY = df2.loc[43]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\KY.txt', dataKY, fmt='%s')

dataLA = df2.loc[44] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\LA.txt', dataLA, fmt='%s')

dataMA = df2.loc[45]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\MA.txt', dataMA, fmt='%s')

dataMD = df2.loc[46] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\MD.txt', dataMD, fmt='%s')

dataME = df2.loc[47]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\ME.txt', dataME, fmt='%s')

dataMI = df2.loc[48] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\MI.txt', dataMI, fmt='%s')

dataMN = df2.loc[49]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\MN.txt', dataMN, fmt='%s')

dataMO = df2.loc[50] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\MO.txt', dataMO, fmt='%s')

dataWV = df2.loc[51]
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\WV.txt', dataWV, fmt='%s')

dataWY = df2.loc[52] 
np.savetxt(r'c:\Users\dking\AndroidStudioProjects\HelloWorld\app\src\main\assets\WY.txt', dataWY, fmt='%s')

#df.to_csv(r'c:\Users\dking\AndroidStudioProjects\PA1.txt', header=, index=None, sep=',', mode='a')
